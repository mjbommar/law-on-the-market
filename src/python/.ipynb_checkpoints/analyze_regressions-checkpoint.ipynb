# %%
# %matplotlib inline

# Imports
import matplotlib.pyplot as plt
import numpy
import os
import pandas
import re
import scipy.stats
import seaborn
import string

# sklearn
import sklearn
import sklearn.tree
import sklearn.utils

# Style
seaborn.set_style("darkgrid")

# %%
# Base directory
base_path = "/data/workspace/law-on-the-market/"

# %%
# Read case ticker data
case_ticker_df = pandas.read_csv(os.path.join(base_path, "data", "events", "case_ticker_data.csv"))
case_ticker_df.columns = ["case", "case_disposition", "case_name",
                         "date_argument", "date_decision", "docket",
                         "issue", "issue_area", "law_type", "lc_disagreement",
                         "petitioner", "respondent", "sct_cite", "case_short_name",
                         "term", "index", "symbol", "vote_margin"]
case_ticker_df["index"].fillna("SPY", inplace=True)
case_ticker_df.head().T
# Out:
#                                                                   0  \
# case                                                              1
# case_disposition                                                  4
# case_name         HUNT-WESSON, INC. v. FRANCHISE TAX BOARD OF CA...
# date_argument                                             1/12/2000
# date_decision                                             2/22/2000
# docket                                                      98-2043
# issue                                                         80100
# issue_area                                                        8
# law_type                                                          2
# lc_disagreement                                                   0
# petitioner                                                       25
# respondent                                                        4
# sct_cite                                             120 S.Ct. 1022
# ...

# %%
case_ticker_df.groupby(["case", "index", "symbol"])["case_name"].count().sort_values(ascending=False).head()
# Out:
# case  index  symbol
# 211   XTL    XLY       1
# 71    XLI    CBE       1
# 78    SPY    YRCW      1
#       XLI    YRCW      1
# 80    SPY    DF        1
# Name: case_name, dtype: int64

# %%
case_ticker_df.drop_duplicates(subset=["case", "index", "symbol"], inplace=True)

# %%
# Read case test stats
case_stat_df = pandas.read_csv(os.path.join(base_path, "output", "lotm_event_stats.csv"), index_col=0)
case_stat_df.columns = ["case", "index", "symbol", "estimate", "error", 
                        "t_value", "p_value", "sig", "date_decision", 
                        "sct_cite", "term", "docket", "case_short_name"]
print(case_stat_df.shape)
case_stat_df.head().T
# Out:
# (1573, 13)
#                                                       1  \
# case                                                  1
# index                                               SPY
# symbol                                              CAG
# estimate                                       0.007026
# error                                          0.050674
# t_value                                        0.138651
# p_value                                        0.889726
# sig                                                 NaN
# date_decision                                 2/22/2000
# sct_cite                                 120 S.Ct. 1022
# term                                               1999
# docket                                          98-2043
# case_short_name  Hunt-Wesson v. Franchise Tax Bd. of CA
#
#                                                       2  \
# case                                                  1
# ...

# %%
case_stat_df.groupby(["case", "index", "symbol"])["docket"].count().sort_values(ascending=False).head()
# Out:
# case  index  symbol
# 31    WLB    WLB       2
#              CLD       2
#              ACI       2
#              BTU       2
# 100   IYZ    TFX       1
# Name: docket, dtype: int64

# %%
case_stat_df.drop_duplicates(subset=["case", "index", "symbol"], inplace=True)

# %%
#case_stat_df.set_index(["case", "index", "symbol"], drop=True, inplace=True)

# %%
# Merge tests and ticker data
all_stat_df = pandas.merge(case_stat_df, case_ticker_df, on=["case", "index", "symbol"], how="left")
all_stat_df.loc[:, "abs_estimate"] = all_stat_df["estimate"].abs()
all_stat_df.head().T
# Out:
#                                                                    0  \
# case                                                               1
# index                                                            SPY
# symbol                                                           CAG
# estimate                                                    0.007026
# error                                                       0.050674
# t_value                                                     0.138651
# p_value                                                     0.889726
# sig                                                              NaN
# date_decision_x                                            2/22/2000
# sct_cite_x                                            120 S.Ct. 1022
# term_x                                                          1999
# docket_x                                                     98-2043
# case_short_name_x             Hunt-Wesson v. Franchise Tax Bd. of CA
# ...

# %%
all_stat_df.loc[:, "delay_argued"] = (pandas.to_datetime(all_stat_df["date_decision_x"]) - pandas.to_datetime(all_stat_df["date_argument"]))
all_stat_df.loc[:, "delay_argued"] = all_stat_df.loc[:, "delay_argued"].apply(lambda x: x.days if not pandas.isnull(x) else -1)

# %%
all_stat_df.loc[:, ["estimate", "error", "t_value", "p_value", "lc_disagreement", "delay_argued", "vote_margin"]].corr()
# Out:
#                  estimate     error   t_value   p_value  lc_disagreement  \
# estimate         1.000000  0.101143  0.765456  0.037217         0.011447
# error            0.101143  1.000000  0.111403  0.103141        -0.027870
# t_value          0.765456  0.111403  1.000000  0.145282         0.026096
# p_value          0.037217  0.103141  0.145282  1.000000        -0.009450
# lc_disagreement  0.011447 -0.027870  0.026096 -0.009450         1.000000
# delay_argued    -0.012963 -0.120987 -0.022513  0.016932        -0.005671
# vote_margin     -0.034598 -0.104290 -0.020101  0.031746         0.012183
#
#                  delay_argued  vote_margin
# estimate            -0.012963    -0.034598
# error               -0.120987    -0.104290
# t_value             -0.022513    -0.020101
# p_value              0.016932     0.031746
# lc_disagreement     -0.005671     0.012183
# delay_argued         1.000000    -0.067830
# vote_margin         -0.067830     1.000000

# %%
all_stat_df.loc[:, ["estimate", "error", "t_value", "p_value", "lc_disagreement", "delay_argued", "vote_margin"]].corr(method="spearman")
# Out:
#                  estimate     error   t_value   p_value  lc_disagreement  \
# estimate         1.000000  0.004034  0.947670  0.119447         0.027467
# error            0.004034  1.000000  0.047403  0.100608        -0.019387
# t_value          0.947670  0.047403  1.000000  0.142519         0.030875
# p_value          0.119447  0.100608  0.142519  1.000000        -0.008714
# lc_disagreement  0.027467 -0.019387  0.030875 -0.008714         1.000000
# delay_argued    -0.005283 -0.117819 -0.027814 -0.000543         0.083807
# vote_margin      0.007338 -0.128255  0.004363  0.023221        -0.003563
#
#                  delay_argued  vote_margin
# estimate            -0.005283     0.007338
# error               -0.117819    -0.128255
# t_value             -0.027814     0.004363
# p_value             -0.000543     0.023221
# lc_disagreement      0.083807    -0.003563
# delay_argued         1.000000    -0.229375
# vote_margin         -0.229375     1.000000

# %%
all_stat_df.loc[:, ["abs_estimate", "error", "t_value", "p_value", "lc_disagreement", "delay_argued", "vote_margin"]].corr()
# Out:
#                  abs_estimate     error   t_value   p_value  lc_disagreement  \
# abs_estimate         1.000000  0.436649 -0.027561 -0.548536         0.028558
# error                0.436649  1.000000  0.111403  0.103141        -0.027870
# t_value             -0.027561  0.111403  1.000000  0.145282         0.026096
# p_value             -0.548536  0.103141  0.145282  1.000000        -0.009450
# lc_disagreement      0.028558 -0.027870  0.026096 -0.009450         1.000000
# delay_argued        -0.076183 -0.120987 -0.022513  0.016932        -0.005671
# vote_margin         -0.035605 -0.104290 -0.020101  0.031746         0.012183
#
#                  delay_argued  vote_margin
# abs_estimate        -0.076183    -0.035605
# error               -0.120987    -0.104290
# t_value             -0.022513    -0.020101
# p_value              0.016932     0.031746
# lc_disagreement     -0.005671     0.012183
# delay_argued         1.000000    -0.067830
# vote_margin         -0.067830     1.000000

# %%
all_stat_df.loc[:, ["abs_estimate", "error", "t_value", "p_value", "lc_disagreement", "delay_argued", "vote_margin"]].corr(method="spearman")
# Out:
#                  abs_estimate     error   t_value   p_value  lc_disagreement  \
# abs_estimate         1.000000  0.449180 -0.096372 -0.788553         0.004950
# error                0.449180  1.000000  0.047403  0.100608        -0.019387
# t_value             -0.096372  0.047403  1.000000  0.142519         0.030875
# p_value             -0.788553  0.100608  0.142519  1.000000        -0.008714
# lc_disagreement      0.004950 -0.019387  0.030875 -0.008714         1.000000
# delay_argued        -0.054490 -0.117819 -0.027814 -0.000543         0.083807
# vote_margin         -0.063524 -0.128255  0.004363  0.023221        -0.003563
#
#                  delay_argued  vote_margin
# abs_estimate        -0.054490    -0.063524
# error               -0.117819    -0.128255
# t_value             -0.027814     0.004363
# p_value             -0.000543     0.023221
# lc_disagreement      0.083807    -0.003563
# delay_argued         1.000000    -0.229375
# vote_margin         -0.229375     1.000000

# %%
all_stat_df["vote_margin"].describe()
# Out:
# count    1289.000000
# mean        5.845617
# std         3.091297
# min         0.000000
# 25%         3.000000
# 50%         7.000000
# 75%         9.000000
# max         9.000000
# Name: vote_margin, dtype: float64

# %%
non_null_index = -all_stat_df["vote_margin"].isnull()
print(scipy.stats.pearsonr(all_stat_df.loc[non_null_index, "estimate"],
                     all_stat_df.loc[non_null_index, "vote_margin"]))
print(scipy.stats.spearmanr(all_stat_df.loc[non_null_index, "estimate"],
                     all_stat_df.loc[non_null_index, "vote_margin"]))
# Out:
# (-0.034597597413032019, 0.21449058316846029)
# SpearmanrResult(correlation=0.0073375590844412097, pvalue=0.79240741449208718)

# %%
non_null_index = -all_stat_df["vote_margin"].isnull()
print(scipy.stats.pearsonr(all_stat_df.loc[non_null_index, "abs_estimate"],
                     all_stat_df.loc[non_null_index, "vote_margin"]))
print(scipy.stats.spearmanr(all_stat_df.loc[non_null_index, "abs_estimate"],
                     all_stat_df.loc[non_null_index, "vote_margin"]))
# Out:
# (-0.035605276214722779, 0.20142984208490491)
# SpearmanrResult(correlation=-0.063523791319059678, pvalue=0.022562458111189052)

# %%
all_stat_df.shape
# Out:
# (1569, 30)

# %%
# Build model to help understand by issue area
all_stat_df.groupby("issue_area")["estimate"].count()
# Out:
# issue_area
# 1.0     106
# 2.0      65
# 3.0      17
# 4.0       6
# 5.0      29
# 6.0       8
# 7.0      47
# 8.0     629
# 9.0     207
# 10.0    160
# 11.0      3
# 12.0      5
# Name: estimate, dtype: int64

# %%
# Build model to help understand by issue area
all_stat_df.groupby("issue_area")["estimate"].mean().sort_values()
# Out:
# issue_area
# 3.0    -0.012159
# 5.0    -0.007974
# 11.0   -0.005811
# 1.0    -0.005316
# 7.0    -0.003952
# 8.0    -0.002149
# 12.0    0.000804
# 2.0     0.000917
# 9.0     0.001660
# 10.0    0.004080
# 4.0     0.007973
# 6.0     0.008048
# Name: estimate, dtype: float64

# %%
# Build model to help understand by issue area
all_stat_df.groupby("issue_area")["estimate"].std().sort_values()
# Out:
# issue_area
# 11.0    0.002998
# 6.0     0.007274
# 4.0     0.009883
# 2.0     0.016988
# 5.0     0.017394
# 7.0     0.021733
# 9.0     0.022185
# 12.0    0.023129
# 8.0     0.029758
# 3.0     0.035632
# 10.0    0.039030
# 1.0     0.047282
# Name: estimate, dtype: float64

# %%
import io
issue_area_df = pandas.read_csv(io.StringIO("""1	Criminal Procedure
2	Civil Rights
3	First Amendment
4	Due Process
5	Privacy
6	Attorneys
7	Unions
8	Economic Activity
9	Judicial Power
10	Federalism
11	Interstate Relations
12	Federal Taxation
13	Miscellaneous
14	Private Action"""), sep="\t", header=None)
issue_area_df.columns = ["code", "name"]
issue_area_df.set_index("code", inplace=True)
issue_area_df.head()
# Out:
#                     name
# code
# 1     Criminal Procedure
# 2           Civil Rights
# 3        First Amendment
# 4            Due Process
# 5                Privacy

# %%
# Sort order
issue_area_sort_order = all_stat_df.groupby("issue_area")["estimate"].median().sort_values().index

# Plot violin for issue area/estimate
ax = seaborn.boxplot(x="estimate", y="issue_area", data=all_stat_df, orient="h", order=issue_area_sort_order)
_ = ax.set_yticklabels(issue_area_df.loc[issue_area_sort_order, "name"])
_ = ax.set_ylabel("Issue Area")
_ = ax.set_xlabel("Event Estimate (Abnormal Return)")
_ = ax.set_xlim(-0.15, 0.15)
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_issue_area.pdf"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_issue_area.eps"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_issue_area.png"), dpi=400, figsize=(8,6))

# %%
# Sort order
issue_area_sort_order = all_stat_df.groupby("issue_area")["abs_estimate"].median().sort_values().index

# Plot violin for issue area/estimate
ax = seaborn.boxplot(x="abs_estimate", y="issue_area", data=all_stat_df, orient="h", order=issue_area_sort_order)
_ = ax.set_yticklabels(issue_area_df.loc[issue_area_sort_order, "name"])
_ = ax.set_ylabel("Issue Area")
_ = ax.set_xlabel("Event Estimate Magnitude (Abnormal Return)")
_ = ax.set_xlim(0.0, 0.3)
plt.savefig(os.path.join(base_path, "figures", "event_estimate_magnitude_by_issue_area.pdf"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_magnitude_by_issue_area.eps"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_magnitude_by_issue_area.png"), dpi=400, figsize=(8,6))

# %%
party_code_string = io.StringIO("""1	attorney general of the United States, or his office
2	specified state board or department of education
3	city, town, township, village, or borough government or governmental unit
4	state commission, board, committee, or authority
5	county government or county governmental unit, except school district
6	court or judicial district
7	state department or agency
8	governmental employee or job applicant
9	female governmental employee or job applicant
10	minority governmental employee or job applicant
11	minority female governmental employee or job applicant
12	not listed among agencies in the first Administrative Action variable
13	retired or former governmental employee
14	U.S. House of Representatives
15	interstate compact
16	judge
17	state legislature, house, or committee
18	local governmental unit other than a county, city, town, township, village, or borough
19	governmental official, or an official of an agency established under an interstate compact
20	state or U.S. supreme court
21	local school district or board of education
22	U.S. Senate
23	U.S. senator
24	foreign nation or instrumentality
25	state or local governmental taxpayer, or executor of the estate of
26	state college or university
27	United States
28	State
100	person accused, indicted, or suspected of crime
101	advertising business or agency
102	agent, fiduciary, trustee, or executor
103	airplane manufacturer, or manufacturer of parts of airplanes
104	airline
105	distributor, importer, or exporter of alcoholic beverages
106	alien, person subject to a denaturalization proceeding, or one whose citizenship is revoked
107	American Medical Association
108	National Railroad Passenger Corp.
109	amusement establishment, or recreational facility
110	arrested person, or pretrial detainee
111	attorney, or person acting as such;includes bar applicant or law student, or law firm or bar association
112	author, copyright holder
113	bank, savings and loan, credit union, investment company
114	bankrupt person or business, or business in reorganization
115	establishment serving liquor by the glass, or package liquor store
116	water transportation, stevedore
117	bookstore, newsstand, printer, bindery, purveyor or distributor of books or magazines
118	brewery, distillery
119	broker, stock exchange, investment or securities firm
120	construction industry
121	bus or motorized passenger transportation vehicle
122	business, corporation
123	buyer, purchaser
124	cable TV
125	car dealer
126	person convicted of crime
127	tangible property, other than real estate, including contraband
128	chemical company
129	child, children, including adopted or illegitimate
130	religious organization, institution, or person
131	private club or facility
132	coal company or coal mine operator
133	computer business or manufacturer, hardware or software
134	consumer, consumer organization
135	creditor, including institution appearing as such; e.g., a finance company
136	person allegedly criminally insane or mentally incompetent to stand trial
137	defendant
138	debtor
139	real estate developer
140	disabled person or disability benefit claimant
141	distributor
142	person subject to selective service, including conscientious objector
143	drug manufacturer
144	druggist, pharmacist, pharmacy
145	employee, or job applicant, including beneficiaries of
146	employer-employee trust agreement, employee health and welfare fund, or multi-employer pension plan
147	electric equipment manufacturer
148	electric or hydroelectric power utility, power cooperative, or gas and electric company
149	eleemosynary institution or person
150	environmental organization
151	employer. If employer's relations with employees are governed by the nature of the employer's business (e.g., railroad, boat), rather than labor law generally, the more specific designation is used in place of Employer.
152	farmer, farm worker, or farm organization
153	father
154	female employee or job applicant
155	female
156	movie, play, pictorial representation, theatrical production, actor, or exhibitor or distributor of
157	fisherman or fishing company
158	food, meat packing, or processing company, stockyard
159	foreign (non-American) nongovernmental entity
160	franchiser
161	franchisee
162	lesbian, gay, bisexual, transexual person or organization
163	person who guarantees another's obligations
164	handicapped individual, or organization of devoted to
165	health organization or person, nursing home, medical clinic or laboratory, chiropractor
166	heir, or beneficiary, or person so claiming to be
167	hospital, medical center
168	husband, or ex-husband
169	involuntarily committed mental patient
170	Indian, including Indian tribe or nation
171	insurance company, or surety
172	inventor, patent assigner, trademark owner or holder
173	investor
174	injured person or legal entity, nonphysically and non-employment related
175	juvenile
176	government contractor
177	holder of a license or permit, or applicant therefor
178	magazine
179	male
180	medical or Medicaid claimant
181	medical supply or manufacturing co.
182	racial or ethnic minority employee or job applicant
183	minority female employee or job applicant
184	manufacturer
185	management, executive officer, or director, of business entity
186	military personnel, or dependent of, including reservist
187	mining company or miner, excluding coal, oil, or pipeline company
188	mother
189	auto manufacturer
190	newspaper, newsletter, journal of opinion, news service
191	radio and television network, except cable tv
192	nonprofit organization or business
193	nonresident
194	nuclear power plant or facility
195	owner, landlord, or claimant to ownership, fee interest, or possession of land as well as chattels
196	shareholders to whom a tender offer is made
197	tender offer
198	oil company, or natural gas producer
199	elderly person, or organization dedicated to the elderly
200	out of state noncriminal defendant
201	political action committee
202	parent or parents
203	parking lot or service
204	patient of a health professional
205	telephone, telecommunications, or telegraph company
206	physician, MD or DO, dentist, or medical society
207	public interest organization
208	physically injured person, including wrongful death, who is not an employee
209	pipe line company
210	package, luggage, container
211	political candidate, activist, committee, party, party member, organization, or elected official
212	indigent, needy, welfare recipient
213	indigent defendant
214	private person
215	prisoner, inmate of penal institution
216	professional organization, business, or person
217	probationer, or parolee
218	protester, demonstrator, picketer or pamphleteer (non-employment related), or non-indigent loiterer
219	public utility
220	publisher, publishing company
221	radio station
222	racial or ethnic minority
223	person or organization protesting racial or ethnic segregation or discrimination
224	racial or ethnic minority student or applicant for admission to an educational institution
225	realtor
226	journalist, columnist, member of the news media
227	resident
228	restaurant, food vendor
229	retarded person, or mental incompetent
230	retired or former employee
231	railroad
232	private school, college, or university
233	seller or vendor
234	shipper, including importer and exporter
235	shopping center, mall
236	spouse, or former spouse
237	stockholder, shareholder, or bondholder
238	retail business or outlet
239	student, or applicant for admission to an educational institution
240	taxpayer or executor of taxpayer's estate, federal only
241	tenant or lessee
242	theater, studio
243	forest products, lumber, or logging company
244	person traveling or wishing to travel abroad, or overseas travel agent
245	trucking company, or motor carrier
246	television station
247	union member
248	unemployed person or unemployment compensation applicant or claimant
249	union, labor organization, or official of
250	veteran
251	voter, prospective voter, elector, or a nonelective official seeking reapportionment or redistricting of legislative districts (POL)
252	wholesale trade
253	wife, or ex-wife
254	witness, or person under subpoena
255	network
256	slave
257	slave-owner
258	bank of the united states
259	timber company
260	u.s. job applicants or employees
301	Army and Air Force Exchange Service
302	Atomic Energy Commission
303	Secretary or administrative unit or personnel of the U.S. Air Force
304	Department or Secretary of Agriculture
305	Alien Property Custodian
306	Secretary or administrative unit or personnel of the U.S. Army
307	Board of Immigration Appeals
308	Bureau of Indian Affairs
310	Bonneville Power Administration
311	Benefits Review Board
312	Civil Aeronautics Board
313	Bureau of the Census
314	Central Intelligence Agency
315	Commodity Futures Trading Commission
316	Department or Secretary of Commerce
317	Comptroller of Currency
318	Consumer Product Safety Commission
319	Civil Rights Commission
320	Civil Service Commission, U.S.
321	Customs Service or Commissioner of Customs
322	Defense Base Closure and REalignment Commission
323	Drug Enforcement Agency
324	Department or Secretary of Defense (and Department or Secretary of War)
325	Department or Secretary of Energy
326	Department or Secretary of the Interior
327	Department of Justice or Attorney General
328	Department or Secretary of State
329	Department or Secretary of Transportation
330	Department or Secretary of Education
331	U.S. Employees' Compensation Commission, or Commissioner
332	Equal Employment Opportunity Commission
333	Environmental Protection Agency or Administrator
334	Federal Aviation Agency or Administration
335	Federal Bureau of Investigation or Director
336	Federal Bureau of Prisons
337	Farm Credit Administration
338	Federal Communications Commission (including a predecessor, Federal Radio Commission)
339	Federal Credit Union Administration
340	Food and Drug Administration
341	Federal Deposit Insurance Corporation
342	Federal Energy Administration
343	Federal Election Commission
344	Federal Energy Regulatory Commission
345	Federal Housing Administration
346	Federal Home Loan Bank Board
347	Federal Labor Relations Authority
348	Federal Maritime Board
349	Federal Maritime Commission
350	Farmers Home Administration
351	Federal Parole Board
352	Federal Power Commission
353	Federal Railroad Administration
354	Federal Reserve Board of Governors
355	Federal Reserve System
356	Federal Savings and Loan Insurance Corporation
357	Federal Trade Commission
358	Federal Works Administration, or Administrator
359	General Accounting Office
360	Comptroller General
361	General Services Administration
362	Department or Secretary of Health, Education and Welfare
363	Department or Secretary of Health and Human Services
364	Department or Secretary of Housing and Urban Development
366	Interstate Commerce Commission
367	Indian Claims Commission
368	Immigration and Naturalization Service, or Director of, or District Director of, or Immigration and Naturalization Enforcement
369	Internal Revenue Service, Collector, Commissioner, or District Director of
370	Information Security Oversight Office
371	Department or Secretary of Labor
372	Loyalty Review Board
373	Legal Services Corporation
374	Merit Systems Protection Board
375	Multistate Tax Commission
376	National Aeronautics and Space Administration
377	Secretary or administrative unit of the U.S. Navy
378	National Credit Union Administration
379	National Endowment for the Arts
380	National Enforcement Commission
381	National Highway Traffic Safety Administration
382	National Labor Relations Board, or regional office or officer
383	National Mediation Board
384	National Railroad Adjustment Board
385	Nuclear Regulatory Commission
386	National Security Agency
387	Office of Economic Opportunity
388	Office of Management and Budget
389	Office of Price Administration, or Price Administrator
390	Office of Personnel Management
391	Occupational Safety and Health Administration
392	Occupational Safety and Health Review Commission
393	Office of Workers' Compensation Programs
394	Patent Office, or Commissioner of, or Board of Appeals of
395	Pay Board (established under the Economic Stabilization Act of 1970)
396	Pension Benefit Guaranty Corporation
397	U.S. Public Health Service
398	Postal Rate Commission
399	Provider Reimbursement Review Board
400	Renegotiation Board
401	Railroad Adjustment Board
402	Railroad Retirement Board
403	Subversive Activities Control Board
404	Small Business Administration
405	Securities and Exchange Commission
406	Social Security Administration or Commissioner
407	Selective Service System
408	Department or Secretary of the Treasury
409	Tennessee Valley Authority
410	United States Forest Service
411	United States Parole Commission
412	Postal Service and Post Office, or Postmaster General, or Postmaster
413	United States Sentencing Commission
414	Veterans' Administration
415	War Production Board
416	Wage Stabilization Board
417	General Land Office of Commissioners
418	Transportation Security Administration
419	Surface Transportation Board
420	U.S. Shipping Board Emergency Fleet Corp.
421	Reconstruction Finance Corp.
501	Unidentifiable
600	International Entity""")
party_code_df = pandas.read_csv(party_code_string, sep="\t", header=None)
party_code_df.columns=["code", "name"]
party_code_df.set_index("code", inplace=True, drop=True)
party_code_df.loc[:, "name"] = party_code_df.loc[:, "name"].apply(lambda x: x[0:min(len(x), 32)])
party_code_df.head()
# Out:
#                                   name
# code
# 1     attorney general of the United S
# 2     specified state board or departm
# 3     city, town, township, village, o
# 4     state commission, board, committ
# 5     county government or county gove

# %%
# Sort order
petitioner_sort_order = all_stat_df.groupby("petitioner")["estimate"].median().sort_values().index

# Plot violin for issue area/estimate
f, ax = plt.subplots(1, 1, figsize=(8, 16))
seaborn.boxplot(x="estimate", y="petitioner", data=all_stat_df, orient="h", order=petitioner_sort_order, ax=ax)
_ = ax.set_yticklabels(party_code_df.loc[petitioner_sort_order, "name"])
_ = ax.set_ylabel("petitioner")
_ = ax.set_xlabel("Event Estimate (Abnormal Return)")
_ = ax.set_xlim(-0.1, 0.1)
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_petitioner.pdf"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_petitioner.eps"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_petitioner.png"), dpi=400, figsize=(8,6))

# %%
# Sort order
respondent_sort_order = all_stat_df.groupby("respondent")["estimate"].median().sort_values().index

# Plot violin for issue area/estimate
f, ax = plt.subplots(1, 1, figsize=(8, 16))
seaborn.boxplot(x="estimate", y="respondent", data=all_stat_df, orient="h", order=respondent_sort_order, ax=ax)
_ = ax.set_yticklabels(party_code_df.loc[respondent_sort_order, "name"])
_ = ax.set_ylabel("Respondent")
_ = ax.set_xlabel("Event Estimate (Abnormal Return)")
_ = ax.set_xlim(-0.1, 0.1)
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_respondent.pdf"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_respondent.eps"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_respondent.png"), dpi=400, figsize=(8,6))

# %%
# Plot violin for LC dispute/estimate
ax = seaborn.boxplot(x="estimate", y="lc_disagreement", data=all_stat_df, orient="h")
#_ = ax.set_yticklabels(issue_area_df.loc[issue_area_sort_order, "name"])
_ = ax.set_ylabel("Lower Court Disagreement")
_ = ax.set_xlabel("Event Estimate (Abnormal Return)")
_ = ax.set_xlim(-0.15, 0.15)
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_lc_disagreement.pdf"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_lc_disagreement.eps"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_lc_disagreement.png"), dpi=400, figsize=(8,6))

# %%
# Sort order
vote_margin_sort_order = all_stat_df.groupby("vote_margin")["estimate"].median().sort_values().index


# Plot violin for LC dispute/estimate
ax = seaborn.boxplot(x="estimate", y="vote_margin", data=all_stat_df, orient="h")#, order=vote_margin_sort_order)
#_ = ax.set_yticklabels(issue_area_df.loc[issue_area_sort_order, "name"])
_ = ax.set_ylabel("Vote Margin")
_ = ax.set_xlabel("Event Estimate (Abnormal Return)")
_ = ax.set_xlim(-0.15, 0.15)
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_vote_margin.pdf"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_vote_margin.eps"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_vote_margin.png"), dpi=400, figsize=(8,6))

# %%
# Sort order
vote_margin_sort_order = all_stat_df.groupby("vote_margin")["abs_estimate"].median().sort_values().index


# Plot violin for LC dispute/estimate
ax = seaborn.boxplot(x="abs_estimate", y="vote_margin", data=all_stat_df, orient="h")#, order=vote_margin_sort_order)
#_ = ax.set_yticklabels(issue_area_df.loc[issue_area_sort_order, "name"])
_ = ax.set_ylabel("Vote Margin")
_ = ax.set_xlabel("Event Estimate Magnitude (Abnormal Return)")
_ = ax.set_xlim(-0.15, 0.15)
plt.savefig(os.path.join(base_path, "figures", "event_estimate_magnitude_by_vote_margin.pdf"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_magnitude_by_vote_margin.eps"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_magnitude_by_vote_margin.png"), dpi=400, figsize=(8,6))

# %%
case_disposition_df = pandas.DataFrame([[1, "Stay"],
                                        [2, "Affirmed"],
                                        [3, "Reversed"],
                                        [4, "Reversed and Remanded"],
                                        [5, "Vacated and Remanded"],
                                        [6, "Affirmed and Reversed in Part"],
                                        [7, "Affirmed and Reversed and Remanded in Part"],
                                        [8, "Vacated"],
                                        [9, "Petition Denied"],
                                        [10, "Cert to Lower Court"],
                                        [11, "No Disposition"],
                                       ],
                                      columns=["code", "name"])
case_disposition_df.set_index("code", inplace=True, drop=True)
case_disposition_df.head()
# Out:
#                        name
# code
# 1                      Stay
# 2                  Affirmed
# 3                  Reversed
# 4     Reversed and Remanded
# 5      Vacated and Remanded

# %%
# Sort order
case_disposition_sort_order = all_stat_df.groupby("case_disposition")["estimate"].median().sort_values().index

# Plot violin for LC dispute/estimate
ax = seaborn.boxplot(x="estimate", y="case_disposition", data=all_stat_df, orient="h", order=case_disposition_sort_order)
_ = ax.set_yticklabels(case_disposition_df.loc[case_disposition_sort_order, "name"])
_ = ax.set_ylabel("case_disposition")
_ = ax.set_xlabel("Event Estimate (Abnormal Return)")
_ = ax.set_xlim(-0.15, 0.15)
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_case_disposition.pdf"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_case_disposition.eps"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_case_disposition.png"), dpi=400, figsize=(8,6))

# %%
# Sector data subset
good_index = []
good_index.extend([c for c in all_stat_df["index"].unique() if c.lower().startswith("xl")])
sector_data_subset_df = all_stat_df.loc[all_stat_df["index"].isin(good_index)]

# Sort order
index_sort_order = sector_data_subset_df.groupby("index")["estimate"].median().sort_values().index

# Plot violin for LC dispute/estimate
ax = seaborn.boxplot(x="estimate", y="index", data=sector_data_subset_df, orient="h", order=index_sort_order)
#_ = ax.set_yticklabels(issue_area_df.loc[issue_area_sort_order, "name"])
_ = ax.set_ylabel("Index/Sector")
_ = ax.set_xlabel("Event Estimate (Abnormal Return)")
_ = ax.set_xlim(-0.15, 0.15)
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_index.pdf"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_index.eps"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_by_index.png"), dpi=400, figsize=(8,6))

# %%
# Sector data subset
good_index = []
good_index.extend([c for c in all_stat_df["index"].unique() if c.lower().startswith("xl")])
sector_data_subset_df = all_stat_df.loc[all_stat_df["index"].isin(good_index)]

# Sort order
index_sort_order = sector_data_subset_df.groupby("index")["abs_estimate"].median().sort_values().index

# Plot violin for LC dispute/estimate
ax = seaborn.boxplot(x="abs_estimate", y="index", data=sector_data_subset_df, orient="h", order=index_sort_order)
#_ = ax.set_yticklabels(issue_area_df.loc[issue_area_sort_order, "name"])
_ = ax.set_ylabel("Index/Sector")
_ = ax.set_xlabel("Event Estimate Magnitude (Abnormal Return)")
_ = ax.set_xlim(0.0, 0.3)
plt.savefig(os.path.join(base_path, "figures", "event_estimate_magnitude_by_index.pdf"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_magnitude_by_index.eps"), dpi=400, figsize=(8,6))
plt.savefig(os.path.join(base_path, "figures", "event_estimate_magnitude_by_index.png"), dpi=400, figsize=(8,6))

# %%
(all_stat_df["vote_margin"]==0).mean()
# Out:
# 0.0063734862970044612

# %%
ax = all_stat_df.groupby("vote_margin")["estimate"].median().plot(kind="bar")
ax.set_xlabel("Vote Margin (Justices)")
ax.set_ylabel("Standard Deviation of Estimates")

# %%
#plt.scatter(all_stat_df["delay_argued"], all_stat_df["estimate"])
all_stat_df.loc[:, "delay_argued_months"] = all_stat_df.loc[:, "delay_argued"].apply(lambda x: int(x / 30))
estimate_by_delay = all_stat_df.groupby("delay_argued_months")["estimate"].mean().sort_index()
estimate_std_by_delay = all_stat_df.groupby("delay_argued_months")["estimate"].std().sort_index()

#plt.errorbar(x=estimate_by_delay.index, y=estimate_by_delay, yerr=estimate_std_by_delay)
f, ax = plt.subplots(ncols=1, nrows=1, figsize=(12,6))
seaborn.factorplot(x="delay_argued_months", y="estimate", hue="case_disposition", data=all_stat_df, ax=ax)

# %%
ax = seaborn.tsplot(data=estimate_by_delay)

# %%
all_stat_df.loc[:, "petitioner_name"] = all_stat_df.loc[:, "petitioner"].apply(lambda x: party_code_df.loc[x, "name"] if not pandas.isnull(x) else "")
all_stat_df.loc[:, "respondent_name"] = all_stat_df.loc[:, "respondent"].apply(lambda x: party_code_df.loc[x, "name"] if not pandas.isnull(x) else "")
all_stat_df.loc[:, "case_disposition_name"] = all_stat_df.loc[:, "case_disposition"].apply(lambda x: case_disposition_df.loc[x, "name"] if not pandas.isnull(x) else "")

# %%
petitioner_respondent_count = all_stat_df.groupby(["petitioner_name", "respondent_name"])["estimate"].count()
print(petitioner_respondent_count.sort_values(ascending=False).head())
petitioner_respondent_count = petitioner_respondent_count.unstack()
# Out:
# petitioner_name                   respondent_name
#                                                                       280
# computer business or manufacture  computer business or manufacture     50
# professional organization, busin  Environmental Protection Agency      49
# oil company, or natural gas prod  investor                             43
# Federal Trade Commission          drug manufacturer                    36
# Name: estimate, dtype: int64

# %%
petitioner_respondent_count = all_stat_df.groupby(["petitioner_name", "respondent_name", "case_disposition_name"])["estimate"].count()
print(petitioner_respondent_count.sort_values(ascending=False).head())
# Out:
# petitioner_name                   respondent_name                   case_disposition_name
#                                                                                                      280
# professional organization, busin  Environmental Protection Agency   Affirmed and Reversed in Part     49
# computer business or manufacture  computer business or manufacture  Reversed                          43
# oil company, or natural gas prod  investor                          Vacated and Remanded              43
# Federal Trade Commission          drug manufacturer                 Reversed                          36
# Name: estimate, dtype: int64

# %%
petitioner_respondent_estimate = all_stat_df.groupby(["petitioner_name", "respondent_name"])["estimate"].mean()
print(petitioner_respondent_estimate.sort_values(ascending=False).head())
print(petitioner_respondent_estimate.sort_values(ascending=False).tail())
petitioner_respondent_estimate = petitioner_respondent_estimate.unstack()
# Out:
# petitioner_name                   respondent_name
# mining company or miner, excludi  environmental organization          0.135617
# inventor, patent assigner, trade  inventor, patent assigner, trade    0.079689
# Unidentifiable                    drug manufacturer                   0.071984
# consumer, consumer organization   bank, savings and loan, credit u    0.068956
# employer. If employer's relation  racial or ethnic minority employ    0.068695
# Name: estimate, dtype: float64
# petitioner_name                   respondent_name
# broker, stock exchange, investme  investor                           -0.035422
# retail business or outlet         manufacturer                       -0.044051
# heir, or beneficiary, or person   employer-employee trust agreemen   -0.044796
# United States                     cable TV                           -0.046083
# owner, landlord, or claimant to   tenant or lessee                   -0.048748
# Name: estimate, dtype: float64

# %%
petitioner_respondent_estimate = all_stat_df.groupby(["petitioner_name", "respondent_name", "case_disposition_name"])["estimate"].mean()
print(petitioner_respondent_estimate.sort_values(ascending=False).head(10))
print(petitioner_respondent_estimate.sort_values(ascending=False).tail(10))
# Out:
# petitioner_name                   respondent_name                   case_disposition_name
# mining company or miner, excludi  environmental organization        Reversed and Remanded    0.135617
# inventor, patent assigner, trade  inventor, patent assigner, trade  Reversed and Remanded    0.107222
# drug manufacturer                 patient of a health professional  Affirmed                 0.099778
# Unidentifiable                    drug manufacturer                 Affirmed                 0.071984
# consumer, consumer organization   bank, savings and loan, credit u  Reversed and Remanded    0.068956
# employer. If employer's relation  racial or ethnic minority employ  Affirmed                 0.068695
# United States                     governmental official, or an off  Reversed and Remanded    0.054778
# health organization or person, n  physician, MD or DO, dentist, or  Reversed and Remanded    0.039098
# ...

# %%
all_stat_df.to_csv(os.path.join(base_path, "output", "lotm_scdb_stats.csv"), encoding="utf-8", index=False)
